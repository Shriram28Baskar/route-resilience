# %% [markdown]
# # ISRO Route Resilience - Validation and Benchmark
#
# This notebook demonstrates the quantitative validation of the Route Resilience graph criticality metrics against real-world disaster data, specifically the Chennai 2015 / Kerala 2018 floods.
#
# ## Metric: Precision@K
# Of the top K nodes flagged as critical by our betweenness/cascade simulation, how many actually failed or caused significant bottlenecks during the real disaster event?
