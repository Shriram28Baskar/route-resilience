# %% [markdown]
# # Validation — NOT YET RUN
#
# **Status: no validation has been performed. This notebook contains no code.**
#
# It previously described a Precision@K methodology against the Chennai 2015 and
# Kerala 2018 floods. The figures quoted in the README from that description
# (Precision@5 = 4/5, Precision@10 = 8/10) were **never computed** — there is no
# code here, and no ground-truth file exists anywhere in the repository. Those
# claims have been withdrawn; see `CLAIMS.md`.
#
# ## What this notebook needs before it can make any claim
#
# 1. A committed OSM road graph (`backend/data/graphs/osm_fallback.gpickle`).
#    This environment cannot reach Overpass, so it was never obtained.
# 2. A frozen, independently sourced ground-truth set of road failures for one
#    dated event, with a per-record provenance table, committed **before** the
#    first evaluation is run.
# 3. Baselines to compare against: degree centrality, random selection, and a
#    naive elevation threshold.
# 4. Bootstrap confidence intervals on every reported figure.
#
# Items 1 and 2 are P2 work and are deliberately not started. Whatever
# Precision@K this eventually yields must be published as computed, including
# if it shows betweenness underperforming a naive baseline.
